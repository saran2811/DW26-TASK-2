# %% [markdown]
# <a href="https://colab.research.google.com/github/saran2811/DW26-TASK-2/blob/main/mongo_task_5_nov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pymongo import MongoClient
import pandas as pd

# %%
saran=MongoClient("mongodb://saranraj:Hulk1997@ac-0c0n4vt-shard-00-00.olc1fqw.mongodb.net:27017,ac-0c0n4vt-shard-00-01.olc1fqw.mongodb.net:27017,ac-0c0n4vt-shard-00-02.olc1fqw.mongodb.net:27017/?ssl=true&replicaSet=atlas-ybjk4f-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
l=saran["studata"]

# %%
s=l["examdetails"]

# %%
df=pd.read_json('/content/students.json',lines=True)
df
# Out:
#      _id              name                                             scores
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# [200 rows x 3 columns]

# %%
df1=df.to_dict("records")
df1

# %%
s.insert_many(df1)

# %% [markdown]
# # ** Find the student name who scored maximum scores in all (exam, quiz and homework)?**

# %%
L=[]
for i in s.find({}):
    e=i["scores"][0]["score"]
    q=i["scores"][1]["score"]
    h=i["scores"][2]["score"]
    t=e+q+h   
    i['total']=t
    L.append(i)
T=pd.DataFrame(L)

# %%
print("Student name who scored max in all types:")
print(T['name'].iloc[T["total"].idxmax()])
# Out:
# Student name who scored max in all types:
# Jessika Dagenais

# %% [markdown]
# # **Find students who scored below average in the exam and pass mark is 40%?**

# %%
l=[]
for i in s.find({'scores.0.score':{'$gt':40,'$lte':65}},{'_id':0,'name':1}):
     
     l.append(i)

# %%
pd.DataFrame(l)
# Out:
#                  name
# 0    Aurelia Menendez
# 1      Wilburn Spiess
# 2        Denisha Cast
# 3      Quincy Danaher
# 4    Verdell Sowinski
# 5        Gisela Levin
# 6      Tressa Schwing
# 7        Rosana Vales
# 8    Tamika Schildgen
# 9     Gwyneth Garling
# 10       Kayce Kenyon
# 11     Terica Brugger
# 12          Chad Rahe
# 13        Grady Zemke
# 14     Vina Matsunaga
# 15    Jenise Mcguffie
# 16       Adrien Renda
# 17        Efrain Claw
# 18     Mariela Sherer
# 19         Rae Kohout
# 20         Cassi Heal
# 21   Demarcus Audette
# 22   Mercedez Garduno
# 23     Shin Allbright
# 24  Mikaela Meidinger
# 25        Flora Duell
# 26      Gennie Ratner
# 27   Zachary Langlais
# 28     Wilburn Spiess
# 29       Daphne Zheng
# 30       Marcus Blohm
# 31     Quincy Danaher
# 32      Alix Sherrill
# 33     Tambra Mercure
# 34      Dodie Staller
# 35     Tressa Schwing
# 36   Laureen Salomone
# 37    Gwyneth Garling
# 38   Richelle Siemers
# 39      Aleida Elsass
# ...

# %% [markdown]
# # **Find students who scored below pass mark and assigned them as fail, and above pass mark as pass in all the categories.**

# %%
l=[]
for i in s.find({'$and':[{'scores.0.score':{'$lte':40}},{'scores.1.score':{'$lte':40}},{'scores.2.score':{'$lte':40}}]}):
    i["Result"]="Fail"
    l.append(i)
f=pd.DataFrame(l)
f
# Out:
#    _id        name                                             scores Result
# 0    0  aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...   Fail

# %%
l1=[]
for i in s.find({'$and':[{'scores.0.score':{'$gt':40}},{'scores.1.score':{'$gt':40}},{'scores.2.score':{'$gt':40}}]}):
    i["Result"]="pass"
    l1.append(i)
p=pd.DataFrame(l1)

# %%
  
frames = [p,f]
result=pd.concat(frames)
result
# Out:
#     _id               name                                             scores  \
# 0     1   Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 1     7       Salena Olmos  [{'score': 90.37826509157176, 'type': 'exam'},...
# 2    10       Denisha Cast  [{'score': 45.61876862259409, 'type': 'exam'},...
# 3    11       Marcus Blohm  [{'score': 78.42617835651868, 'type': 'exam'},...
# 4    12     Quincy Danaher  [{'score': 54.29841278520669, 'type': 'exam'},...
# 5    13   Jessika Dagenais  [{'score': 90.47179954427436, 'type': 'exam'},...
# 6    18   Verdell Sowinski  [{'score': 62.12870233109035, 'type': 'exam'},...
# 7    20     Tressa Schwing  [{'score': 42.17439799514388, 'type': 'exam'},...
# 8    23   Tamika Schildgen  [{'score': 45.65432764125526, 'type': 'exam'},...
# 9    32         Gwen Honig  [{'score': 87.14345376886205, 'type': 'exam'},...
# 10   36   Eugene Magdaleno  [{'score': 73.055900093666, 'type': 'exam'}, {...
# ...

# %% [markdown]
# # **Find the total and average of the exam, quiz and homework and store them in a separate collection.**

# %%
dic=[]
for i in s.find({}):
    d={}
    e=i["scores"][0]["score"]
    q=i["scores"][1]["score"]
    h=i["scores"][2]["score"]
    t=e+q+h
    a=t/3
    d["id"]=i['_id']
    d["Name"]=i["name"]
    d["Total"]=t
    d["Avgerage"]=a
    dic.append(d)

df=pd.DataFrame(dic)
df1=df.to_dict("records")
df1
# Out:
# [{'id': 0,
#   'Name': 'aimee Zank',
#   'Total': 49.11994783171814,
#   'Avgerage': 16.373315943906046},
#  {'id': 1,
#   'Name': 'Aurelia Menendez',
#   'Total': 184.61969202100374,
#   'Avgerage': 61.53989734033458},
#  {'id': 2,
#   'Name': 'Corliss Zuk',
#   'Total': 139.61606947126907,
#   'Avgerage': 46.53868982375636},
#  {'id': 3,
#   'Name': 'Bao Ziglar',
#   'Total': 138.70712252233457,
#   'Avgerage': 46.23570750744486},
#  {'id': 4,
#   'Name': 'Zachary Langlais',
#   'Total': 203.3963625302728,
#   'Avgerage': 67.79878751009093},
#  {'id': 5,
#   'Name': 'Wilburn Spiess',
#   'Total': 134.0186975547794,
#   'Avgerage': 44.67289918492647},
#  {'id': 6,
#   'Name': 'Jenette Flanders',
#   'Total': 147.2203575476617,
#   'Avgerage': 49.07345251588723},
#  {'id': 7,
#   'Name': 'Salena Olmos',
#   'Total': 229.3959334774732,
#   'Avgerage': 76.46531115915774},
#  {'id': 8,
#   'Name': 'Daphne Zheng',
#   'Total': 112.71677331754347,
#   'Avgerage': 37.57225777251449},
# ...

# %%
q=l["stutotal"]
q.insert_many(df1)

# %% [markdown]
# # **   Create a new collection which consists of students who scored below average and above 40% in all the categories.**

# %%
l2=[]
for i in s.find({'$and':[{'scores.0.score':{'$gt':40,'$lte':70}},{'scores.1.score':{'$gt':40,'$lte':70}},{'scores.2.score':{'$gt':40,'$lte':70}}]}):
    l2.append(i)
df2=pd.DataFrame(l2)
bel=df2.to_dict("records")

# %%
y=l["belowavg"]
y.insert_many(bel)

# %% [markdown]
# # **Create a new collection which consists of students who scored below the fail mark in all the categories.**

# %%
s=l["examdetails"]

# %%
l3=[]
for i in s.find({'$and':[{'scores.0.score':{'$lte':40}},{'scores.1.score':{'$lte':40}},{'scores.2.score':{'$lte':40}}]}):   
    l3.append(i)
df3=pd.DataFrame(l3)
col=df3.to_dict("records")

# %%
c=l["falied"]
c.insert_many(col)

# %% [markdown]
# # ** Create a new collection which consists of students who scored above pass mark in all the categories.**

# %%
l4=[]
for i in s.find({'$and':[{'scores.0.score':{'$gt':40}},{'scores.1.score':{'$gt':40}},{'scores.2.score':{'$gt':40}}]}):
   
    l4.append(i)
df4=pd.DataFrame(l1)
pas=df4.to_dict("records")

# %%
d=l["passed"]
d.insert_many(pas)

# %% [markdown]
# # **Telephone Directory CRUD Operation**

# %%
from pymongo import MongoClient
import pandas as pd

# %%
saran=MongoClient("mongodb://saranraj:Hulk1997@ac-0c0n4vt-shard-00-00.olc1fqw.mongodb.net:27017,ac-0c0n4vt-shard-00-01.olc1fqw.mongodb.net:27017,ac-0c0n4vt-shard-00-02.olc1fqw.mongodb.net:27017/?ssl=true&replicaSet=atlas-ybjk4f-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
db=saran["directory"]

# %%
s1=db["tele"]

# %%
direc=[{"id":0,"name":"amar","zone code":"0444","phone number":456841,"address":"454,Anna nagar,Trichy."},{"id":1,"name":"abi","zone code":"0454","phone number":448681,"address":"865,KK nagar,Trichy."},{"id":2,"name":"sashi","zone code":"0462","phone number":266841,"address":"5989,Main road,Madurai."},{"id":3,"name":"bala","zone code":"0464","phone number":450041,"address":"5/8c8,Anna nagar,Madurai."},{"id":4,"name":"tamil","zone code":"0474","phone number":268947,"address":"78/4r,Shastri nagar,Chennai."}]

# %% [markdown]
# # **Inserting to collection**

# %%
s1.insert_many(direc)

# %% [markdown]
# # **Make a query to find records you just created**

# %%
for i in s1.find({}):
  print(i)
# Out:
# {'_id': ObjectId('6361fb8aa55297e4c21658e1'), 'id': 0, 'name': 'amar', 'zone code': '0444', 'phone number': 456841, 'address': '454,Anna nagar,Trichy.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e2'), 'id': 1, 'name': 'abi', 'zone code': '0454', 'phone number': 448681, 'address': '865,KK nagar,Trichy.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e3'), 'id': 2, 'name': 'sashi', 'zone code': '0462', 'phone number': 266841, 'address': '5989,Main road,Madurai.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e4'), 'id': 3, 'name': 'bala', 'zone code': '0464', 'phone number': 450041, 'address': '5/8c8,Anna nagar,Madurai.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e5'), 'id': 4, 'name': 'tamil', 'zone code': '0474', 'phone number': 268947, 'address': '78/4r,Shastri nagar,Chennai.'}

# %% [markdown]
# # **Modify the records, use the update_one() method. The update_one() method requires two arguments, query and update.**

# %%
s1.update_one({"id":4},{"$set":{"name":"raja"}})

# %%
for i in s1.find():
   print(i)
# Out:
# {'_id': ObjectId('6361fb8aa55297e4c21658e1'), 'id': 0, 'name': 'amar', 'zone code': '0444', 'phone number': 456841, 'address': '454,Anna nagar,Trichy.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e2'), 'id': 1, 'name': 'abi', 'zone code': '0454', 'phone number': 448681, 'address': '865,KK nagar,Trichy.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e3'), 'id': 2, 'name': 'sashi', 'zone code': '0462', 'phone number': 266841, 'address': '5989,Main road,Madurai.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e4'), 'id': 3, 'name': 'bala', 'zone code': '0464', 'phone number': 450041, 'address': '5/8c8,Anna nagar,Madurai.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e5'), 'id': 4, 'name': 'raja', 'zone code': '0474', 'phone number': 268947, 'address': '78/4r,Shastri nagar,Chennai.'}

# %% [markdown]
# # **Delete the record, use delete_one() method. delete_one() requires a query parameter which specifies the document to dele**

# %%
s1.delete_one({"id":4})

# %%
for i in s1.find():
   print(i)
# Out:
# {'_id': ObjectId('6361fb8aa55297e4c21658e1'), 'id': 0, 'name': 'amar', 'zone code': '0444', 'phone number': 456841, 'address': '454,Anna nagar,Trichy.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e2'), 'id': 1, 'name': 'abi', 'zone code': '0454', 'phone number': 448681, 'address': '865,KK nagar,Trichy.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e3'), 'id': 2, 'name': 'sashi', 'zone code': '0462', 'phone number': 266841, 'address': '5989,Main road,Madurai.'}
# {'_id': ObjectId('6361fb8aa55297e4c21658e4'), 'id': 3, 'name': 'bala', 'zone code': '0464', 'phone number': 450041, 'address': '5/8c8,Anna nagar,Madurai.'}
